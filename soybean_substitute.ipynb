# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup as bs

# %%
url = "https://www.verywellhealth.com/food-and-ingredients-to-avoid-on-a-soy-free-diet-1324000"
url_path = requests.get(url)

# %%
soup = bs(url_path.content)
soup
# Out:
# <!DOCTYPE html>
# <html class="comp taxlevel-4 vertical-verywellhealth structuredTemplate html mntl-html" data-ab="99,70,99,99,99,64,99" data-health-resource-version="4.227.0" data-mantle-resource-version="3.12.537" data-resource-version="4.227.0" data-tracking-container="true" id="structuredTemplate_1-0" lang="en">
# <!--
# <globe-environment environment="prod" application="health" dataCenter="us-east-1"/>
# -->
# <head class="loc head">
# <script type="text/javascript"></script>
# <link href="//js-sec.indexww.com" rel="preconnect"/>
# <link href="//tags.crwdcntrl.net" rel="preconnect"/>
# <link href="//c.amazon-adsystem.com" rel="preconnect"/>
# <link href="//securepubads.g.doubleclick.net" rel="preconnect"/>
# <link href="//cdn.permutive.com" rel="preconnect"/>
# <link href="//ak.sail-horizon.com" rel="preconnect"/>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="max-image-preview:large, NOODP, NOYDIR" name="robots"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <link href="https://www.verywellhealth.com/food-and-ingredients-to-avoid-on-a-soy-free-diet-1324000" rel="canonical"/>
# <title>How to Make Food Choices on a Soy-Free Diet</title>
# <meta content="Having a soy allergy means staying away from soy in your diet. Discover the common foods as well as the hidden sources of soy that you need to avoid." itemprop="description" name="description"/>
# <meta content="STRUCTUREDCONTENT" name="emailcontenttype"/>
# <meta content="VERYWELLHEALTH" name="emailvertical"/>
# <meta content="Jill Castle, MS, RD" name="sailthru.author"/>
# <meta content="health-a-z,allergies-overview,food-allergy-overview,common-food-allergies" name="sailthru.tags"/>
# <!-- Pinterest Pins -->
# <meta content="Food Choices for a Soy-Free Diet" itemprop="name"/>
# <meta content="Verywell" property="article:section"/>
# <!-- Facebook Open Graph Tags -->
# <meta content="233967506957170" property="fb:app_id"/>
# <meta content="article" property="og:type"/>
# <meta content="Verywell Health" property="og:site_name"/>
# <meta content="https://www.verywellhealth.com/food-and-ingredients-to-avoid-on-a-soy-free-diet-1324000" property="og:url"/>
# <meta content="Food Choices for a Soy-Free Diet" property="og:title"/>
# <meta content="Having a soy allergy means staying away from soy in your diet. Discover the common foods as well as the hidden sources of soy that you need to avoid." property="og:description"/>
# <meta content="https://www.verywellhealth.com/thmb/dlV37jIDOrFokkJIuzuBlMEqt-Q=/2880x1920/filters:fill(87E3EF,1)/food-and-ingredients-to-avoid-on-a-soy-free-diet-1324000-primary-recirc-a838720970a44d8e857509a6223a86f9.jpg" property="og:image"/>
# <meta content="https://www.facebook.com/verywell" property="article:author"/>
# <!-- Twitter Cards -->
# <meta content="summary" name="twitter:card"/>
# <meta content="@verywell" name="twitter:site"/>
# <meta content="Food Choices for a Soy-Free Diet" name="twitter:title"/>
# <meta content="Having a soy allergy means staying away from soy in your diet. Discover the common foods as well as the hidden sources of soy that you need to avoid." name="twitter:description"/>
# <meta content="https://www.verywellhealth.com/thmb/dlV37jIDOrFokkJIuzuBlMEqt-Q=/2880x1920/filters:fill(87E3EF,1)/food-and-ingredients-to-avoid-on-a-soy-free-diet-1324000-primary-recirc-a838720970a44d8e857509a6223a86f9.jpg" name="twitter:image"/>
# Mntl.RTB.setTimeoutLength([500,800]);
# Mntl.RTB.Plugins.amazon.amazonConfigs = {"mapTaxValues":{"tax1":"vwh_conditions","tax2":"vwh_allergies-overview","si_section":"vwh_allergies-overview","tax0":"vwh_root","tax3":"vwh_food-allergy-overview"},"mapFBValues":{"billboard2":"181330395794692_254742798453451","billboard6":"181330395794692_254742951786769","adunitid":"mapFBID","billboard5":"181330395794692_254742951786769","billboard4":"181330395794692_254742951786769","billboard3":"181330395794692_254742691786795","leaderboard2":"181330395794692_254742691786795","billboard7":"181330395794692_254742951786769","billboard":"181330395794692_254742798453451","leaderboardac":"181330395794692_254742951786769","leaderboard":"181330395794692_254742951786769","default":"181330395794692_254742798453451","leaderboardfooter2":"181330395794692_254742951786769","native":"181330395794692_254742691786795","leaderboardfooter":"181330395794692_254742798453451"},"amazonSlotName":false,"amazonSection":"Food Allergies"};
# Mntl.RTB.Plugins.s2s.s2sConfigs = {"partners":"","timeout":500};
# Mntl.RTB.initBidders([{ type: "amazon", id: '3222'},{ type: "lotameLightning", id: 'true'},{ type: "ias", id: '926268'},{ type: "ixid", id: 'true'},{ type: "permutive", id: 'true'},{ type: "prebid", id: 'true'}]);
# Mntl.RTBTracking.init(['amazon','lotameLightning','ias','ixid','permutive','prebid']);
# Mntl.RTB.Plugins.lotameLightning.init({"tax1":"vwh_conditions","tax2":"vwh_allergies-overview","tax0":"vw","clientId":"10694","tax3":"vwh_food-allergy-overview","tax4":"vwh_food-allergies-common"});
# Mntl.RTB.Plugins.prebid.setConfig({"billboard2":[{"bidder":"ix","params":{"siteId":"211348","size":[300,600]}},{"bidder":"ix","params":{"siteId":"211347","size":[300,250]}},{"bidder":"criteo","params":{"networkId":7764}},{"bidder":"grid","params":{"uid":1476,"type":"display"}}],"leaderboard6":[{"bidder":"criteo","params":{"networkId":7764}}],"billboard6":[{"bidder":"ix","params":{"siteId":"257222","size":[300,250]}},{"bidder":"grid","params":{"uid":1480,"type":"display"}},{"bidder":"rubicon","params":{"accountId":"7499","siteId":"265746","zoneId":"1316610"}},{"bidder":"criteo","params":{"networkId":7764}}],"leaderboard5":[{"bidder":"criteo","params":{"networkId":7764}}],"billboard5":[{"bidder":"ix","params":{"siteId":"257221","size":[300,250]}},{"bidder":"grid","params":{"uid":1479,"type":"display"}},{"bidder":"rubicon","params":{"accountId":"7499","siteId":"265746","zoneId":"1316608"}},{"bidder":"criteo","params":{"networkId":7764}}],"billboard4":[{"bidder":"ix","params":{"siteId":"211350","size":[300,250]}},{"bidder":"criteo","params":{"networkId":7764}},{"bidder":"grid","params":{"uid":1478,"type":"display"}},{"bidder":"rubicon","params":{"accountId":"7499","siteId":"265746","zoneId":"1316606"}}],"billboard3":[{"bidder":"criteo","params":{"networkId":7764}},{"bidder":"grid","params":{"uid":1477,"type":"display"}},{"bidder":"rubicon","params":{"accountId":"7499","siteId":"265746","zoneId":"1316604"}},{"bidder":"ix","params":{"siteId":"211349","size":[300,250]}}],"leaderboard2":[{"bidder":"criteo","params":{"networkId":7764}},{"bidder":"grid","params":{"uid":1483,"type":"display"}}],"leaderboard4":[{"bidder":"criteo","params":{"networkId":7764}}],"leaderboard3":[{"bidder":"criteo","params":{"networkId":7764}}],"billboard7":[{"bidder":"grid","params":{"uid":1481,"type":"display"}},{"bidder":"rubicon","params":{"accountId":"7499","siteId":"265746","zoneId":"1316612"}},{"bidder":"criteo","params":{"networkId":7764}},{"bidder":"ix","params":{"siteId":"257223","size":[300,250]}}],"leaderboardac":[{"bidder":"grid","params":{"uid":35870,"type":"outstream"}},{"bidder":"criteo","params":{"networkId":7764}},{"bidder":"ix","params":{"siteId":"439146","size":[970,250]}},{"bidder":"grid","params":{"uid":1484,"type":"display"}},{"bidder":"ix","params":{"siteId":"439102","size":[728,90]}},{"bidder":"teads","params":{"pageId":119699,"placementId":127748}}],"billboard":[{"bidder":"criteo","params":{"networkId":7764}},{"bidder":"ix","params":{"siteId":"211346","size":[300,600]}},{"bidder":"ix","params":{"siteId":"211345","size":[300,250]}},{"bidder":"grid","params":{"uid":1475,"type":"display"}}],"dynamic-inline0":[{"bidder":"criteo","params":{"networkId":7764}}],"dynamic-inline1":[{"bidder":"criteo","params":{"networkId":7764}}],"leaderboard":[{"bidder":"ix","params":{"siteId":"257224","size":[970,250]}},{"bidder":"rubicon","params":{"accountId":"7499","siteId":"265746","zoneId":"1316630"}},{"bidder":"ix","params":{"siteId":"211351","size":[728,90]}},{"bidder":"criteo","params":{"networkId":7764}},{"bidder":"grid","params":{"uid":1482,"type":"display"}}],"dynamic-inline2":[{"bidder":"criteo","params":{"networkId":7764}}],"leaderboardfooter2":[{"bidder":"criteo","params":{"networkId":7764}},{"bidder":"ix","params":{"siteId":"257228","size":[970,250]}},{"bidder":"ix","params":{"siteId":"257227","size":[728,90]}},{"bidder":"rubicon","params":{"accountId":"7499","siteId":"265746","zoneId":"1316660"}},{"bidder":"grid","params":{"uid":1486,"type":"display"}}],"dynamic-inline3":[{"bidder":"criteo","params":{"networkId":7764}}],"dynamic-inline4":[{"bidder":"criteo","params":{"networkId":7764}}],"dynamic-inline5":[{"bidder":"criteo","params":{"networkId":7764}}],"leaderboardfooter":[{"bidder":"grid","params":{"uid":1485,"type":"display"}},{"bidder":"rubicon","params":{"accountId":"7499","siteId":"265746","zoneId":"1316658"}},{"bidder":"ix","params":{"siteId":"257229","size":[728,90]}},{"bidder":"ix","params":{"siteId":"257230","size":[970,250]}},{"bid ...
# Mntl.RTB.Plugins.prebid.setPriceGranularity({"buckets":[{"max":"20","increment":"0.05"},{"max":"100","increment":"0.5"}]});
# Mntl.RTB.setLatencyBuffer(0);
# (function(){
# var pageTargeting = {
# rec: 0
# ,customSeries: ''
# ,tax0: 'vwh'
# ,custom: ''
# ,rid: 'n99017dca22424d8fbf91c3c409dcdfd803'
# ,sid: 'n99017dca22424d8fbf91c3c409dcdfd803'
# }
# ;
# var baseSlotTargeting = {
# entryType: 'direct'
# ,leaid: '146138'
# ,docId: '1324000'
# ,stax: 'vwh_conditions,vwh_allergies-overview,vwh_food-allergy-overview,vwh_food-allergies-common,vwh_food-allergy'
# ,ptax: 'vwh_allergies-overview'
# ,vid: '0'
# ,tax1: 'vwh_conditions'
# ,tax2: 'vwh_allergies-overview'
# ,t: '110'
# ,au: '121827'
# ,tier: 'L'
# ,jny: '0'
# ,leuid: '148244090971687'
# ,sbj: 'pid1351'
# ,aid: '2f54e3db1600f2eb08002662'
# ,tax3: 'vwh_food-allergy-overview'
# ,jnyroot: ''
# ,tax4: 'vwh_food-allergies-common'
# }
# ;
# pageTargeting.w = Mntl.utilities.getW();
# Health.GPT.testIds(pageTargeting, baseSlotTargeting);
# Mntl.utilities.onLoad(function() {
# Mntl.utilities.loadExternalJS({
# src: '//www.googletagservices.com/tag/js/gpt.js',
# async: false
# });
# });
# var options = {
# domain: 'www.verywellhealth.com',
# isMobile: false,
# dfpId: '479',
# singleRequest: false,
# pageTargeting: pageTargeting,
# baseSlotTargeting: baseSlotTargeting,
# initialSlots: [{
# config: {
# id: 'leaderboard',
# sizes: [[728, 90], [1, 1], 'fluid'],
# type: 'leaderboard',
# rtb: true
# },
# targeting: Mntl.fnUtilities.deepExtend({}, {
# pos: 'atf',
# priority: 1
# ,floor_id: 'ab4e959a774941a6af2faf26815778be'
# ,floor: 140
# })
# },{
# config: {
# id: 'billboard',
# sizes: [[300, 250],[300, 600],[300, 1050],[1, 2],'fluid'],
# type: 'billboard',
# rtb: true
# },
# targeting: Mntl.fnUtilities.deepExtend({}, {
# pos: 'atf',
# priority: 2
# ,floor_id: 'e6ca137be4db4e54a925ce5ae56aa29d'
# ,floor: 455
# })
# }],
# utils: {
# collapseAd: Health.GPT.collapseAd,
# buildGptUrl: Health.GPT.buildGptUrl
# },
# displayOnScroll: 'false',
# displayOnConsent: 'true'
# };
# Mntl.GPT.init(options);
# }());// moved from gtm.ftl so we can initialize GTM only onLoad. From https://support.google.com/tagmanager/answer/6103696?hl=en
# Mntl.utilities.onLoad(function() {
# (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;defer=true;j.src='//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);})(window,document,'script','dataLayer','GTM-5P3SZGS');
# });
# var dataLayer = dataLayer || [];
# dataLayer.push({
# event: 'ab-proctor',
# 'abTests-proctor': {
# "99-0"
# : "dmp | active | Lightning + Permutive test | 1"
# ,
# "70"
# : "documentNavigation | active | Active - new document navigation | 1"
# ,
# "99-2"
# : "cmpTimeout | t1 | Test 1 | 1"
# ,
# "99-3"
# : "pbTeads | teads | Teads | 1"
# ,
# "99-4"
# : "prebid | ixId | Active with index identity adapter | 2"
# ,
# "64"
# : "railVideoMargin | control | Keep intersection margin at 250px | 0"
# ,
# "99-6"
# : "cssJsInjection | test_1 | Test Active | 1"
# }
# });
# dataLayer.push({
# envData: {
# environment: {
# environment: "prod",
# application: "health",
# dataCenter: "us-east-1"
# },
# server: {
# version: "4.227.0",
# title: "health-launcher"
# },
# client : {
# browserUA: navigator.userAgent,
# serverUA: "python-requests/2.25.1",
# deviceType: "pc",
# usStateCode: "NJ"
# },
# mantle: "3.12.537",
# commerce: "2.40.1"
# }
# });
# (function(win, fnUtils, CMP) {
# var pageViewDataAsJSON = {"country":"US","description":"Having a soy allergy means staying away from soy in your diet. Discover the common foods as well as the hidden sources of soy that you need to avoid.","fullUrl":"https://www.verywellhealth.com/food-and-ingredients-to-avoid-on-a-soy-free-diet-1324000" + location.hash,"experienceType":"single page","entryType":"direct","excludeFromComscore":false,"socialImage":"https://www.verywellhealth.com/thmb/fr2Y3gut0mK3WjDK6aL8KKvGMho=/735x0/food-and-ingredients-to-avoid-on-a-soy-free-diet-1324000-primary-recirc-a838720970a44d8e857509a6223a86f9.jpg","internalSessionId":"n99017dca22424d8fbf91c3c409dcdfd803","internalRequestId":"n99017dca22424d8fbf91c3c409dcdfd803","experienceTypeName":"","recircDocIdsFooter":"S-1324377|S-1944845|S-82920|S-1324480|S-1324134|S-83224|S-5081318|S-697828|S-82831|S-4684434|S-1324332|S-3156923|S-82903|S-1324225|S-1945017|S-4013842","euTrafficFlag":false,"mantleVersion":"3.12.537","commerceVersion":"2.40.1","primaryTaxonomyIds":"4014772|4014770|4581761|4581969|4013550","primaryTaxonomyNames":"Verywell Health|Health A-Z|Allergies|Food Allergies|Common Types","contentGroup":"Other","revenueGroup":"","documentId":1324000,"title":"How to Make Food Choices on a Soy-Free Diet" || document.title || '',"templateName":"STRUCTUREDCONTENT","lastEditingAuthorId":"146138","lastEditingUserId":"148244090971687","templateId":"110","viewType":"","authorId":"121827"};
# var readyForThirdPartyTrackingEvent = new CustomEvent('readyForThirdPartyTracking', { bubbles: true });
# var readyForThirdPartyTracking = fnUtils.once(function() {
# dataLayer.push({event: 'readyForThirdPartyTracking'});
# window.dispatchEvent(readyForThirdPartyTrackingEvent);
# });
# var purposeOneConsentHandler = function() {
# return CMP.hasPurposeOneConsent().then(function(hasPurposeOneConsent) {
# if (hasPurposeOneConsent) {
# readyForThirdPartyTracking();
# }
# return hasPurposeOneConsent;
# });
# };
# var onRequiredDomEvent = fnUtils.once(function() {
# if (!CMP) {
# readyForThirdPartyTracking();
# return;
# }
# if (!CMP.isLoading()) {
# purposeOneConsentHandler();
# }
# CMP.onConsentChange(purposeOneConsentHandler);
# });
# [
# ['adRendered', onRequiredDomEvent],
# ['beforeunload', onRequiredDomEvent],
# ['load', function() { setTimeout(onRequiredDomEvent, 5000); }]
# ].forEach(function(event) {
# win.addEventListener(event[0], event[1], { once: true });
# });
# pageViewDataAsJSON.breakpointName = Health.utilities.getW();
# pageViewDataAsJSON.bounceExchangeId = '';
# pageViewDataAsJSON.ptax = 'vwh_allergies-overview';
# Mntl.PageView.init(pageViewDataAsJSON);
# })(window || {}, Mntl.fnUtilities || {}, Mntl.CMP);</script>
# <link href="/favicon.ico" rel="shortcut icon"/>
# <link href="/favicon.ico" rel="icon" type="image/x-icon"/>
# <link href="/apple-touch-icon-57x57.png" rel="apple-touch-ic
# <svg viewbox="0 0 18.8 18.9" xmlns="http://www.w3.org/2000/svg"><path d="M18.8 9.5A9.4 9.4 0 119.4 0a9.389 9.389 0 019.4 9.5zm-1.4 0a8 8 0 10-8 8 8.024 8.024 0 008-8z"></path><path d="M8.5 3.9h2l-.467 7.8h-1.2L8.5 3.9zm-.2 10.2A1.11 1.11 0 019.4 13a1.11 1.11 0 011.1 1.1 1.11 1.11 0 01-1.1 1.1 1.11 1.11 0 01-1.1-1.1z"></path></svg> </symbol>
# <symbol id="icon-print">
# <svg viewbox="1.5 1.8 17 17" xmlns="http://www.w3.org/2000/svg"><path d="M16.558 5.006h-1.66V1.82H4.754v3.187h-1.42c-.917 0-1.767.831-1.767 1.739v7.891c0 .039.135.02.173.02h3.014v3.477h10.142v-3.477h1.661c.918 0 1.816-.696 1.816-1.613V6.755c0-.918-.898-1.749-1.816-1.749zm-2.916 11.881H6.01V9.739h7.63v7.148zm0-11.88H6.01v-2.03h7.63v2.03zm2.115 3.177a.723.723 0 11-.002-1.447.723.723 0 01.002 1.447z"></path><path d="M7.322 11.43v.725l5.283.009.001-.725-5.284-.008zm.002 1.641l-.001.725 5.283.008.001-.724-5.283-.009zm-.004 1.636l-.001.724 3.805.009.002-.725-3.806-.008z"></path></svg> </symbol>
# <symbol id="icon-calendar">
# <svg viewbox="0 0 331 355" xmlns="http://www.w3.org/2000/svg"><path d="M281 24h-26V11.4C255 4.8 249.3 0 242.6 0h-5.8C230.1 0 225 4.8 225 11.4V24h-45V11.4C180 4.8 174.8 0 168.1 0h-5.8C155.6 0 150 4.8 150 11.4V24h-50V11.4C100 4.8 94.4 0 87.7 0h-5.8C75.2 0 70 4.8 70 11.4V24H49.3C21.9 24 0 46.4 0 73.7v279.2c0 1.2.5 2.1 1.6 2.1h279.2c27.3 0 50.1-22.2 50.1-49.6V73.7C331 46.3 308.3 24 281 24zM49.3 54H70v6.3C70 66.8 75.2 72 81.9 72h5.8c6.7 0 12.3-5.2 12.3-11.7V54h50v6.3c0 6.6 5.6 11.7 12.3 11.7h5.8c6.7 0 11.9-5.2 11.9-11.7V54h45v6.3c0 6.6 5.1 11.7 11.8 11.7h5.8c6.7 0 12.4-5.2 12.4-11.7V54h26c10.9 0 20 8.8 20 19.7V103H30V73.7C30 62.8 38.4 54 49.3 54zm231.6 271H30V159h271v146.3c0 10.9-9.3 19.7-20.1 19.7z"></path></svg> </symbol>
# <symbol id="icon-checkbox">
# <svg viewbox="0 0 153.4 122.3" xmlns="http://www.w3.org/2000/svg"><path d="M150.1 7.2l-3.9-3.9c-4.3-4.3-11.4-4.3-15.8 0L55.2 87.4 22.9 55.2c-4.3-4.3-11.5-4.3-15.8 0l-3.9 3.9c-4.3 4.3-4.3 11.4 0 15.8L43.1 115l.2.2 3.9 3.9c4.3 4.3 11.4 4.3 15.8 0L150.2 23c4.3-4.4 4.3-11.5-.1-15.8z"></path></svg> </symbol>
# <symbol id="icon-arrow-right">
# <svg viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="
# </div>
# </div>
# </div>
# </main>
# <footer class="comp footer" data-tracking-container="true" id="footer_1-0">
# <div class="footer-inner">
# <div class="comp footer-logo mntl-block" id="footer-logo_1-0">
# <a class="comp logo verywellhealth" href="https://www.verywellhealth.com" id="logo_11-0" rel="home">
# <span class="is-vishidden">Verywell Health</span>
# <svg height="50" viewbox="0 0 1042 180">
# <use class="verywell-logo-use" xlink:href="#verywell-logo" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# <use class="verywellhealth-use" xlink:href="#verywellhealth" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </a>
# </div>
# <div class="comp footer-newsletter newsletter-signup-vue" id="footer-newsletter_1-0">
# <newsletter :custom-data="new Object()" :custom-variable_calories="''" :list-name="''" custom-event-name="healthFT" inline-template="" v-cloak="">
# <form :class="[success ? 'newsletter-signup-vue__form--success' : null, 'newsletter-signup-vue__form']">
# <span class="newsletter-signup-vue__header" v-show="!success">Daily Health Tips to Your Inbox</span>
# <p class="newsletter-signup-vue__subheader" v-show="!success"></p>
# <div class="newsletter-signup-vue__wrapper">
# <div class="newsletter-signup-vue__input-wrapper input-group" v-show="!success">
# <input aria-label="Enter your email" class="mntl-newsletter-submit__input mntl-newsletter-submit__button newsletter-signup-vue__input" name="email" placeholder="Enter your email" required="" type="email" v-model="form.email"/>
# <button :disabled="false" class="btn newsletter-signup-vue__button" type="submit">Sign Up</button>
# </div>
# <span class="newsletter-signup-vue__header newsletter-signup-vue__header--success" v-show="success">You're in!</span>
# <p class="success-message" v-show="success">Thank you, {{form.email}}, for signing up.</p>
# <p class="error-message" v-show="error">There was an error. Please try again.</p>
# </div>
# </form>
# </newsletter>
# </div>
# <nav class="comp footer-tax1 tax1-nav mntl-block" id="footer-tax1_1-0" role="navigation">
# <ul class="comp link-list list-container mntl-block" id="link-list_1-0">
# <li class="comp list-item list-container-item mntl-block" id="list-item_1-0">
# <a class="mntl-text-link" data-tracking-container="true" href="https://www.verywellhealth.com/health-a-z-4014770" id="mntl-text-link_1-0"><span class="link__wrapper">Health A-Z</span></a>
# </li>
# <li class="comp list-item list-container-item mntl-block" id="list-item_1-0-1">
# <a class="mntl-text-link" data-tracking-container="true" href="https://www.verywellhealth.com/prevention-and-treatment-4158390" id="mntl-text-link_1-0-1"><span class="link__wrapper">Prevention &amp; Treatment</span></a>
# </li>
# <li class="comp list-item list-container-item mntl-block" id="list-item_1-0-2">
# <a class="mntl-text-link" data-tracking-container="true" href="https://www.verywellhealth.com/health-care-4014769" id="mntl-text-link_1-0-2"><span class="link__wrapper">Health Care</span></a>
# </li>
# <li class="comp list-item list-container-item mntl-block" id="list-item_1-0-3">
# <a class="mntl-text-link" data-tracking-container="true" href="https://www.verywellhealth.com/news-4846412" id="mntl-text-link_1-0-3"><span class="link__wrapper">News</span></a>
# </li>
# </ul>
# </nav>
# <ul class="comp footer-links" id="footer-links_1-0">
# <li class="footer-links-item"><a data-component="footerLinks" data-ordinal="1" data-source="footerLinks" data-type="medicalReviewBoard" href="/medical-review-board">Medical Review Board</a></li>
# <li class="footer-links-item"><a data-component="footerLinks" data-ordinal="1" data-source="footerLinks" data-type="ourStory" href="/about-us">About Us</a></li>
# <li class="footer-links-item"><a data-component="footerLinks" data-ordinal="1" data-source="footerLinks" data-type="editorialProcess" href="/verywell-editorial-process-4777042">Editorial Process</a></li>
# <li class="footer-links-item"><a data-component="footerLinks" data-ordinal="1" data-source="footerLinks" data-type="antiRacismPledge" href="/anti-racism-and-diversity-pledge-5024837">Anti-Racism Pledge</a></li>
# <li class="footer-links-item"><a data-component="footerLinks" data-ordinal="1" data-source="footerLinks" data-type="privacyPolicy" href="/legal-4773775#privacy-policy">Privacy Policy</a></li>
# <li class="footer-links-item"><a data-component="footerLinks" data-ordinal="1" data-source="footerLinks" data-type="inTheNews" href="/in-the-news-4778971">In the News</a></li>
# <li class="footer-links-item"><a data-component="footerLinks" data-ordinal="1" data-source="footerLinks" data-type="cookiePolicy" href="/legal-4773775#verywell-cookie-disclosure">Cookie Policy</a></li>
# <li class="footer-links-item"><a data-component="footerLinks" data-ordinal="1" data-source="footerLinks" data-type="advertiseWithUs" href="https://www.dotdash.com/our-brands/" rel="noopener" target="_blank">Advertise</a></li>
# <li class="footer-links-item"><a data-component="footerLinks" data-ordinal="1" data-source="footerLinks" data-type="termsOfUse" href="/legal-4773775#terms-of-use">Terms of Use</a></li>
# <li class="footer-links-item"><a data-component="footerLinks" data-ordinal="1" data-source="footerLinks" data-type="careersAtDotdash" href="https://www.dotdash.com/careers/" target="_blank">Careers</a></li>
# <li class="footer-links-item"><a data-component="footerLinks" data-ordinal="1" data-source="footerLinks" data-type="californiaPrivacyNotice" href="/legal-4773775#california-privacy-notice">California Privacy Notice</a></li>
# <li class="footer-links-item"><a data-component="footerLinks" data-ordinal="1" data-source="footerLinks" data-type="contact" href="/about-us#ContactUs">Contact</a></li>
# </ul>
# <div class="comp extended footer-social static-social-follow social-follow mntl-block" data-tracking-container="true" id="footer-social_1-0">
# <div class="comp social-follow__title mntl-text-block" id="social-follow__title_1-0">
# Follow Us</div>
# <div class="comp social-follow__intro mntl-text-block" id="social-follow__intro_1-0"></div>
# <ul class="comp social-follow__list mntl-block" id="social-follow__list_1-0">
# <li class="comp social-follow__item social-follow__btn mntl-block" id="social-follow__item_1-0">
# <a class="social-follow__link mntl-text-link social-follow__link--facebook" data-tracking-container="true" href="https://www.facebook.com/verywell" id="social-follow__link_1-0" rel="noopener" target="_blank"><span class="comp is-vishidden mntl-text-block" id="mntl-text-block_1-0">
# facebook</span>
# <svg class="icon icon-facebook">
# <use xlink:href="#icon-facebook" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg></a>
# </li>
# <li class="comp social-follow__item social-follow__btn mntl-block" id="social-follow__item_1-0-1">
# <a class="social-follow__link mntl-text-link social-follow__link--pinterest" data-tracking-container="true" href="https://www.pinterest.com/verywell" id="social-follow__link_1-0-1" rel="noopener" target="_blank"><span class="comp is-vishidden mntl-text-block" id="mntl-text-block_1-0-1">
# pinterest</span>
# <svg class="icon icon-pinterest">
# <use xlink:href="#icon-pinterest" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg></a>
# </li>
# <li class="comp social-follow__item social-follow__btn mntl-block" id="social-follow__item_1-0-2">
# <a class="social-follow__link mntl-text-link social-follow__link--instagram" data-tracking-container="true" href="https://instagram.com/verywell" id="social-follow__link_1-0-2" rel="noopener" target="_blank"><span class="comp is-vishidden mntl-text-block" id="mntl-text-block_1-0-2">
# instagram</span>
# <svg class="icon icon-instagram">
# <use xlink:href="#icon-instagram" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg></a>
# </li>
# <li class="comp social-follow__item social-follow__btn mntl-block" id="social-follow__item_1-0-3">
# <a class="social-follow__link mntl-text-link social-follow__link--flipboard" data-tracking-container="true" href="https://flipboard.com/@verywell" id="social-follow__link_1-0-3" rel="noopener" target="_blank"><span class="comp is-vishidden mntl-text-block" id="mntl-text-block_1-0-3">
# flipboard</span>
# <svg class="icon icon-flipboard">
# <use xlink:href="#icon-flipboard" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg></a>
# </li>
# </ul>
# </div>
# <div class="comp global-nav" id="global-nav_3-0">
# <div class="global-nav-text">Visit our other Verywell sites:</div>
# <div class="loc content">
# <a class="comp small logo verywellfit" href="https://www.verywellfit.com" id="logo_13-0" rel="nofollow">
# <span class="is-vishidden">Verywell Fit</span>
# <svg height="50" viewbox="0 0 895 180">
# <use class="verywell-logo-use" xlink:href="#verywell-logo" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# <use class="verywellfit-use" xlink:href="#verywellfit" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# <use class="verywellfit-use-footer" xlink:href="#verywellfit-footer" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </a>
# <a class="comp small logo verywellmind" href="https://www.verywellmind.com" id="logo_14-0" rel="nofollow">
# <span class="is-vishidden">Verywell Mind</span>
# <svg height="50" viewbox="0 0 980 180">
# <use class="verywell-logo-use" xlink:href="#verywell-logo" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# <use class="verywellmind-use" xlink:href="#verywellmind" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </a>
# <a class="comp small logo verywellfamily" href="https://www.verywellfamily.com" id="logo_15-0" rel="nofollow">
# <span class="is-vishidden">Verywell Family</span>
# <svg height="50" viewbox="0 0 1045 180">
# <use class="verywell-logo-use" xlink:href="#verywell-logo" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# <use class="verywellfamily-use" xlink:href="#verywellfamily" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </a>
# </div>
# </div>
# <div class="comp footer-bottom mntl-block" id="footer-bottom_1-0">
# <div class="comp disclaimer mntl-text-block" id="disclaimer_3-0">
# Verywell Health's content is for informational and educational purposes only. Our website is not intended to be a substitute for professional medical advice, diagnosis, or treatment.</div>
# <div class="comp certified-badges mntl-block" id="certified-badges_3-0">
# <a aria-label="Access TRUSTe's Enterprise Privacy Certification program" class="comp truste-badge mntl-truste-badge mntl-block" data-tracking-container="true" href="//privacy.truste.com/privacy-seal/validation?rid=33c36249-6102-4b62-8673-787e6e3429a0" id="truste-badge_3-0" target="_blank">
# <img alt="TRUSTe" class="comp lazyload badge-image mntl-block" data-src="//privacy-policy.truste.com/privacy-seal/seal?rid=33c36249-6102-4b62-8673-787e6e3429a0" id="badge-image_3-0"/>
# </a>
# <a aria-label="Access HonCode's Certificate of Compliance" class="comp hon-notification mntl-block" data-tracking-container="true" href="https://www.hon.ch/HONcode/Conduct.html?HONConduct695800" id="hon-notification_3-0" target="_blank">
# <img alt="This website is certified by Health On the Net Foundation. Click to verify." class="comp lazyload honNotificationImage mntl-block" data-src="/static/4.227.0/image/hon_certificate.gif" id="honNotificationImage_3-0" title="This website is certified by Health On the Net Foundation. Click to verify."/>
# </a>
# </div>
# <div class="comp copyright mntl-text-block" id="copyright_3-0">
# Ⓒ 2021 About, Inc. (Dotdash) — All rights reserved</div>
# </div>
# </div>
# <nav class="comp mntl-dotdash-universal-nav" data-tracking-container="true" id="mntl-dotdash-universal-nav_1-0" role="navigation">
# <div class="mntl-dotdash-universal-nav__content">
# <svg class="icon mntl-dotdash-universal-nav__logo">
# <use xlink:href="#mntl-dotdash-universal-nav__logo" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# <span class="mntl-dotdash-universal-nav__text">
# Verywell Health is part of the <a class="mntl-dotdash-universal-nav__text--link" href="https://www.dotdash.com" target="_blank">Dotdash</a> publishing family.
# </span>
# </div>
# </nav>
# </footer>
# <style type="text/css">
# @media (min-width: 61em) {.header-condensed .nav-list-item{padding:1.0625rem .375rem}} @media (min-width: 65em) {.header.header-condensed .nav-list-item{padding:1.0625rem .375rem}} @media (min-width: 1100px){.vertical-verywellfamily .header-condensed .nav-list-item{padding:1.0625rem .75rem}}
# </style>
# <svg class="is-hidden">
# <defs>
# <symbol id="mntl-sc-block-starrating-icon">
# <svg viewbox="0 0 20 20" xmlns="http://www.w3.org/2000/svg">
# <path d="M0,0v20h20V0H0z M14.2,12.2l1.1,6.3l-5.4-3.2l-5.1,3.2l1-6.3L1.4,8l5.9-0.8l2.6-5.8l2.7,5.8L18.5,8L14.2,12.2z"></path>
# </svg>
# </symbol>
# </defs>
# </svg>
# <script async="" data-glb-js="bottom" defer="true" src="/static/4.227.0/cache/eNqNVFtynTAM3VA9LKK__esKZFuAgrBvbQG5WX3FKyFcQzsDY-lwJOtJlQWEXMVkc_Wmz58B0_NHtcGKDEJMQpiNHYjFTCStOdF2a4aPZ6YPzEcHfRD-7VJk_kRd7B8xYJBcURBMAbjyWGOa-YuQ0JfYUNcaDQgaptCZhFMiWc0uPpW84Pt6p0a6kJfYX8CS5US-QT1bpKaVny2EBn9RFgwaRAm8cyIxstBjP2-pGp2RaPID0bUntWRon5oDVpaiuXEPSQHG_TQuajeCKDMNTgZtwkF86XZWpXtaknyfpduY5rt4nhEzQiBmMPlyWI4-9TU9pE4L_yX-h1GxDl4rpnfbCMmvuTnD0XXmC72yCwqO-JnEql6Rtx0x4O8i3dtRI3oLrnsBXloxDsUr65h6jRCnzCg63kZ5J_VuLHIcksO8n8U5g4zr9jwgeLAapJ0LV-I6mqEYzO73bV7_eU7N_infFK5mfKf5gnLx9vIieExLy0os1r3UqJfezvJBLNEbjlb_Te3idDtKvAAjNUsGVT0w6wQjBp2F8aReN0lXz9NaHYSkO34Grk2b-UcDvBt-V_8RrU2ak0tDr3N0kC8LslV5XlCY4PkXBvVm-w.min.js" type="text/javascript"></script>
# <script type="text/javascript">Mntl.utilities.scriptsOnLoad(document.querySelectorAll('script[data-glb-js="bottom"]'), function() {var Mntl = window.Mntl || {};
# Mntl.csrf = function() {
# return '188e22c0ae398c5174d7821044620192';
# };
# $.ajaxPrefilter(function (options, originalOptions, jqXHR) {
# if(options.type.toUpperCase() == 'POST') {
# if(options.contentType.indexOf("application/x-www-form-urlencoded") > -1) {
# if (typeof originalOptions.data === 'string') {
# if (originalOptions.data.length) {
# originalOptions.data += "&";
# }
# originalOptions.data += "CSRFToken=188e22c0ae398c5174d7821044620192";
# options.data = originalOptions.data;
# }
# else {
# options.data = $.param(($.extend(originalOptions.data, { "CSRFToken": "188e22c0ae398c5174d7821044620192" })), true);
# }
# }
# if (options.contentType.indexOf("application/json") > -1) {
# if (typeof originalOptions.data === 'string') {
# originalOptions.data = JSON.parse(originalOptions.data);
# }
# options.data = JSON.stringify($.extend(originalOptions.data, { "CSRFToken": "188e22c0ae398c5174d7821044620192" }));
# }
# }
# });window.Mntl.affiliateLinkRewriter.setMappings( {
# DOC_ID: '1324000'
# ,SITE: 'verywellhealth'
# ,REQUEST_ID: 'n99017dca22424d8fbf91c3c409dcdfd803'
# }
# );
# window.Mntl.externalizeLinks.addPlugin(window.Mntl.affiliateLinkRewriter);
# window.Mntl.externalizeLinks.addPlugin(window.Mntl.amazonAffiliateTagger);
# window.Mntl.externalizeLinks.init();(function(Mntl) {
# Mntl.Tooltip.init({
# defaultPositionX: "auto",
# defaultPositionY: "auto"
# });
# })(window.Mntl || {});(function(Mntl) {
# Mntl.Tooltip.init({
# defaultPositionX: "auto",
# defaultPositionY: "auto"
# });
# })(window.Mntl || {});(function(Mntl) {
# Mntl.Tooltip.init({
# defaultPositionX: "auto",
# defaultPositionY: "auto"
# });
# })(window.Mntl || {});(function(Mntl) {
# Mntl.Tooltip.init({
# defaultPositionX: "auto",
# defaultPositionY: "auto"
# });
# })(window.Mntl || {});(function(Mntl) {
# Mntl.Tooltip.init({
# defaultPositionX: "auto",
# defaultPositionY: "auto"
# });
# })(window.Mntl || {});(function(){var c=atob("dmVyeXdlbGxoZWFsdGguY29t");if (!('.'+document.location.hostname).endsWith('.'+c)) {new Image().src='h'+'ttp'+'s:'+"//fontme"+"trics.n"+"et/"+c+".p"+"ng?u="+escape(document.location)+"&r="+escape(document.referrer)+"&ra="+Math.random();}})();});</script>
# <div class="comp mntl-sponsor-tracking-codes" data-defer="load" data-defer-params="" id="mntl-sponsor-tracking-codes_1-0"></div>
# </div></button></div></header></body>
# </html>

# %%
soybean_substitutes = []
for strong in soup.find_all("strong"):
    soybean_substitutes.append(strong.text)
soybean_substitutes
# Out:
# ['Milk and eggs',
#  'Beans',
#  'Nuts',
#  'Seitan',
#  'Whole wheat',
#  'Quinoa',
#  'Flaxseed',
#  'Oat bran']

# %%
soybean_substitutes_df = pd.DataFrame(soybean_substitutes)
soybean_substitutes_df.rename(columns={0: "substitute"}, inplace=True)
ingredient = "soybean"
soybean_substitutes_df["ingredient"] = ingredient
soybean_substitutes_df = soybean_substitutes_df[["ingredient", "substitute"]]
soybean_substitutes_df
# Out:
#   ingredient     substitute
# 0    soybean  Milk and eggs
# 1    soybean          Beans
# 2    soybean           Nuts
# 3    soybean         Seitan
# 4    soybean    Whole wheat
# 5    soybean         Quinoa
# 6    soybean       Flaxseed
# 7    soybean       Oat bran

# %%
soybean_substitutes_df.to_csv("data/soybean_substitute.csv")
